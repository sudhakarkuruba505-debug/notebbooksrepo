# %%
# %sql
--Create catalog to organize data and tables in medallian Architecture for data warehousing
create catalog bank

# %%
# %sql
--create schemas inside the bank catalog for data organizing like bronze(same data from source) -> silver (transformed) -> gold(analtical ready data)
--bronze schema
create schema bank.bronze;

--silver schema
create schema bank.silver;

--gold schema
create schema bank.gold
