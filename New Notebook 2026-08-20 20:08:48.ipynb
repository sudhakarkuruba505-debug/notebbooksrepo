# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.window import Window

# %%
#read data from as database 
df=spark.read.format("jdbc")\
    .option("url","jdbc:mysql://localhost:3306/retail_db")\
        .option("dbtable","departments")\
            .option("user","root")\
                .option("password","sudhakar@505")\
                    .option("driver","com.mysql.jdbc.Driver")\
                        .load()

# %%
frame=spark.read.csv("/Workspace/Users/sudhakarkuruba000@gmail.com/branches.csv",inferSchema=True,header=True,sep=',')
windows_spec=Window.partitionBy("status").orderBy("date")
new_frame=frame.withColumn("rank",rank().over(windows_spec))
display(new_frame)

# %%
#create schema
schema=StructType([
    StructField("brach-id",StringType(),True)
])
